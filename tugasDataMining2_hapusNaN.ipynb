# %% [markdown]
# # Data Cleaning dengan Menghapus seluruh nilai NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
df=pd.read_csv("C:/Users/Gilbert Ciady/Documents/Visual Studio Code Project/Semester 3/Data Mining/Tugas 2/heart_disease_uci.csv")

# %%
nan_data = df[df.isna().any(axis=1)]
nan_data
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 87    88   53  Female      Cleveland      non-anginal     128.0  216.0  False
# 166  167   52    Male      Cleveland      non-anginal     138.0  223.0  False
# 192  193   43    Male      Cleveland     asymptomatic     132.0  247.0   True
# 266  267   52    Male      Cleveland     asymptomatic     128.0  204.0   True
# 287  288   58    Male      Cleveland  atypical angina     125.0  220.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.dropna(inplace = True)
print (df.to_string())
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs           restecg  thalch  exang  oldpeak        slope   ca               thal  num
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True    lv hypertrophy   150.0  False      2.3  downsloping  0.0       fixed defect    0
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False    lv hypertrophy   108.0   True      1.5         flat  3.0             normal    2
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False    lv hypertrophy   129.0   True      2.6         flat  2.0  reversable defect    1
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False            normal   187.0  False      3.5  downsloping  0.0             normal    0
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False    lv hypertrophy   172.0  False      1.4    upsloping  0.0             normal    0
# ...

# %%
print("Informasi Dataset: ")
df_info = pd.DataFrame({
    'Data Type': df.dtypes.values,
    'Entry': df.count().values,
    'Column': df.columns
})
df_info.index = range(1, len(df_info) + 1)
print(tabulate(df_info, headers='keys', tablefmt='outline'))
# Out:
# Informasi Dataset:
# +----+-------------+---------+----------+
# |    | Data Type   |   Entry | Column   |
# +====+=============+=========+==========+
# |  1 | int64       |     299 | id       |
# |  2 | int64       |     299 | age      |
# |  3 | object      |     299 | sex      |
# |  4 | object      |     299 | dataset  |
# |  5 | object      |     299 | cp       |
# |  6 | float64     |     299 | trestbps |
# |  7 | float64     |     299 | chol     |
# |  8 | object      |     299 | fbs      |
# |  9 | object      |     299 | restecg  |
# | 10 | float64     |     299 | thalch   |
# | 11 | object      |     299 | exang    |
# | 12 | float64     |     299 | oldpeak  |
# | 13 | object      |     299 | slope    |
# | 14 | float64     |     299 | ca       |
# | 15 | object      |     299 | thal     |
# | 16 | int64       |     299 | num      |
# +----+-------------+---------+----------+

# %%
missing_values =df.isnull().sum().reset_index()
missing_values.columns =['Column', 'Missing Values']
missing_values.index = range(1, len(missing_values) + 1)
print("Missing Value: ")
print(tabulate(missing_values, headers='keys', tablefmt='outline'))
# Out:
# Nilai Missing atau Nilai yang Hilang:
# +----+----------+------------------+
# |    | Column   |   Missing Values |
# +====+==========+==================+
# |  1 | id       |                0 |
# |  2 | age      |                0 |
# |  3 | sex      |                0 |
# |  4 | dataset  |                0 |
# |  5 | cp       |                0 |
# |  6 | trestbps |                0 |
# |  7 | chol     |                0 |
# |  8 | fbs      |                0 |
# |  9 | restecg  |                0 |
# | 10 | thalch   |                0 |
# | 11 | exang    |                0 |
# | 12 | oldpeak  |                0 |
# | 13 | slope    |                0 |
# | 14 | ca       |                0 |
# | 15 | thal     |                0 |
# | 16 | num      |                0 |
# +----+----------+------------------+

# %%
desc_stats = df.describe().reset_index()
desc_stats.index = range(1, len(desc_stats) + 1)
print(tabulate(desc_stats, headers='keys', tablefmt='outline'))
# Out:
# +----+---------+----------+-----------+------------+----------+----------+-----------+------------+------------+
# |    | index   |       id |       age |   trestbps |     chol |   thalch |   oldpeak |         ca |        num |
# +====+=========+==========+===========+============+==========+==========+===========+============+============+
# |  1 | count   | 299      | 299       |   299      | 299      | 299      | 299       | 299        | 299        |
# |  2 | mean    | 153.873  |  54.5217  |   131.716  | 246.786  | 149.328  |   1.05853 |   0.672241 |   0.946488 |
# |  3 | std     |  95.8963 |   9.03026 |    17.7478 |  52.5326 |  23.1211 |   1.16277 |   0.937438 |   1.23041  |
# |  4 | min     |   1      |  29       |    94      | 100      |  71      |   0       |   0        |   0        |
# |  5 | 25%     |  75.5    |  48       |   120      | 211      | 132.5    |   0       |   0        |   0        |
# ...
